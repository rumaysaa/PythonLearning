# %%
import time
while True:
    with open("../files/myfile.txt") as f:
        print(f.read())
        time.sleep(3)
# Out:
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# party party yeahhhhh
# carbonara
# tony montana
# ding dong
# excusee meeeeeee
#
# Lachimolala
# ...
